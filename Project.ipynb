# %%
"""1. Загрузить файл hr.csv
2. Рассчитать основные статистики для переменных (среднее, медиана, мода, мин/макс, сред. отклонение)
3. Рассчитать и визуализировать корреляционную матрицу для переменных
4. Визуализировать несколько взаимосвязей между переменными
5. С использованием t-test статистики проверить взаимосвязи между несколькими переменными
6. Рассчитать сколько работников работает в каждом департаменте
7. Показать распределение сотрудников по зарплатам
8. Показать распределение сотрудников по зарплатам совместно с департаментами
9. Сколько сотрудников покинули компанию
10. Проверить несколько гипотез для данных, чтобы понять почему сотрудники покидают компанию
11. Загрузить результат (в формате .ipynb ноутбука) в репозиторий. Разместить ссылку на репозиторий в лк на сайте"""
# Out:
# '1. Загрузить файл hr.csv\n2. Рассчитать основные статистики для переменных (среднее, медиана, мода, мин/макс, сред. отклонение)\n3. Рассчитать и визуализировать корреляционную матрицу для переменных\n4. Визуализировать несколько взаимосвязей между переменными\n5. С использованием t-test статистики проверить взаимосвязи между несколькими переменными\n6. Рассчитать сколько работников работает в каждом департаменте\n7. Показать распределение сотрудников по зарплатам\n8. Показать распределение сотрудников по зарплатам совместно с департаментами\n9. Сколько сотрудников покинули компанию\n10. Проверить несколько гипотез для данных, чтобы понять почему сотрудники покидают компанию\n11. Загрузить результат (в формате .ipynb ноутбука) в репозиторий. Разместить ссылку на репозиторий в лк на сайте'

# %%
import pandas as pd
import statistics as st
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import kurtosis
from scipy.stats import skew
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
#1.Загрузка файла HR.csv
hr = pd.read_csv('C:\\Users\\Alexey\\Desktop\\pythonbysics\\ProjectWork\\HR.csv')

# %%
#2. Информация о данных
hr.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
hr.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
hr.median()
# Out:
# satisfaction_level         0.64
# last_evaluation            0.72
# number_project             4.00
# average_montly_hours     200.00
# time_spend_company         3.00
# Work_accident              0.00
# left                       0.00
# promotion_last_5years      0.00
# dtype: float64

# %%
hr.mode().loc[0]
# Out:
# satisfaction_level         0.1
# last_evaluation           0.55
# number_project               4
# average_montly_hours       135
# time_spend_company           3
# Work_accident                0
# left                         0
# promotion_last_5years        0
# sales                    sales
# salary                     low
# Name: 0, dtype: object

# %%
#3. Корреляционная матрица для переменных
corr = hr.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
#4. Взаимосвязь между переменными (average_montly_hours и last_evaluation) и (satisfaction_level и average_montly_hours)
g = sns.pairplot(hr, vars=['average_montly_hours', 'last_evaluation'],
                 kind='scatter')
g.fig.set_size_inches(10,10)

# %%
g = sns.pairplot(hr, vars=['satisfaction_level', 'average_montly_hours'],
                 kind='scatter')
g.fig.set_size_inches(15,15)

# %%
#5. Проаерка t-test статистики взаимосвязи между несколькими переменными
sales = hr[hr['sales']=='sales']
marketing = hr[hr['sales']=='marketing']
management = hr[hr['sales']=='management']
IT = hr[hr['sales']=='IT']

# %%
stats.ttest_ind(sales['average_montly_hours'], marketing['average_montly_hours'])
# Out:
# Ttest_indResult(statistic=0.8212001474299715, pvalue=0.41157145594534483)

# %%
stats.ttest_ind(sales['average_montly_hours'], management['average_montly_hours'])
# Out:
# Ttest_indResult(statistic=-0.16031777143129528, pvalue=0.8726375516747543)

# %%
stats.ttest_ind(management['satisfaction_level'], IT['satisfaction_level'])
# Out:
# Ttest_indResult(statistic=0.2697230314368249, pvalue=0.7874033407158763)

# %%
stats.ttest_ind(sales['satisfaction_level'], marketing['satisfaction_level'])
# Out:
# Ttest_indResult(statistic=-0.4443819266830463, pvalue=0.6567857260510299)

# %%
#6. Сколько работников работает в каждом департаменте?
hr['sales'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: sales, dtype: int64

# %%
#7. Распределение по зарплатам(с графиком)
hr['salary'].value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
hr.groupby('salary').count()['sales'].plot(kind='bar')

# %%
#8. Распределение по зарплатам совместно с департаментами(с графиком)
salary = hr.groupby(['sales', 'salary']).count()['satisfaction_level'].reset_index()
hr_salary = salary.pivot_table(
                        index='sales', 
                        columns='salary', 
                        values='satisfaction_level', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.set(font_scale=1)
g = hr_salary.plot(kind='bar', rot=45, stacked=True)

# %%
#9. Сколько сотрудников покинуло компанию?
hr['left'].value_counts()
#Ответ: 3571 сотрудник
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
#10. Проверка гипотез
#H1 - cотрудники уходят из-за низкой зарплаты
left = hr.groupby(['left', 'salary']).count()['satisfaction_level'].reset_index()
left = left.pivot_table(
                        index='left', 
                        columns='salary', 
                        values='satisfaction_level', 
                        aggfunc=sum).fillna(0).applymap(float)
left
# Out:
# salary    high     low  medium
# left
# 0       1155.0  5144.0  5129.0
# 1         82.0  2172.0  1317.0

# %%
sns.set(font_scale=1)
g = left.plot(kind='bar', rot=45, stacked=True)
#Итог: Наибольшее кол-во ушедших сотрудников - сотрудники с маленькой зарплатой. С высокой - наименьшее

# %%
# H2 - сотрудники уходят из-за низкого уровня удовлетворенности
left = hr[hr['left']==1]

l = left.groupby('satisfaction_level').count().reset_index()
l = l[['satisfaction_level', 'salary']].sort_values('salary', ascending=False)

def level_satisfaction(row):
    if row['satisfaction_level'] < 0.25:
        res = '<0.25'
    elif row['satisfaction_level'] < 0.5:
        res = 'from 0.25 to 0.5'
    elif row['satisfaction_level'] < 0.75:
        res = 'from 0.5 to 0.75'
    else:
        res = 'from 0.75 to 1'
    return res      

l['level_satisfaction'] = l.apply(level_satisfaction, axis=1)

# %%
l = l.groupby('level_satisfaction')['salary'].sum()
l
# Out:
# level_satisfaction
# <0.25                931
# from 0.25 to 0.5    1616
# from 0.5 to 0.75     218
# from 0.75 to 1       806
# Name: salary, dtype: int64

# %%
l.plot(kind='bar')

# %%
#Итог: Большее число сотрудников покинуло компанию из-за уровня удовлетворенности меньше 50%(2547 из 3571)

# %%
#H3 - Много сотрудников уходит с течением времени
not_left =  hr[hr['left']==0]

# %%
not_left['time_spend_company'].hist()

# %%
#Итог: По графику видно, что средний сотрудник проводит в компании примерно 2-4 года

# %%
#Также необходимо узнать, из каких отделов чаще всего уходят сотрудники
left = hr.groupby(['left', 'sales']).count()['satisfaction_level'].reset_index()
left = left.pivot_table(
                        index='sales', 
                        columns='left', 
                        values='satisfaction_level', 
                        aggfunc=sum).fillna(0).applymap(float)
left
# Out:
# left              0       1
# sales
# IT            954.0   273.0
# RandD         666.0   121.0
# accounting    563.0   204.0
# hr            524.0   215.0
# management    539.0    91.0
# marketing     655.0   203.0
# product_mng   704.0   198.0
# sales        3126.0  1014.0
# support      1674.0   555.0
# technical    2023.0   697.0

# %%
sns.set(font_scale=1)
g = left.plot(kind='bar', rot=45, stacked=True)

# %%
#На графике видно, что максимальные потери сотрудников в областях: sales, support и technical
